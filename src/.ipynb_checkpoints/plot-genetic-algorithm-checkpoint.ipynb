# %%
# import libraries
import numpy as np
np.set_printoptions(precision = 4, suppress = True)
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import gaussian_kde

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
out_dir = "./data/out"
optim_dir = os.path.join(out_dir,"genetic-algorithm")
res_dir = os.path.join(optim_dir, "51-xrp-max-2085.22")

# %%
progress = pd.read_csv(os.path.join(res_dir, "progress.csv"))
progress.tail(10)
# Out:
#     mean fitness  best fitness  population size
# 30   1329.933669   2062.357910              574
# 31   1334.273781   2061.231689              576
# 32   1366.312619   2085.218994              578
# 33   1374.718021   2085.218994              580
# 34   1377.168541   2085.218994              582
# 35   1361.142753   2085.218994              584
# 36   1385.018181   2085.218994              586
# 37   1382.949082   2085.218994              588
# 38   1403.066385   2085.218994              590
# 39   1396.326029   2085.218994              592

# %%
mean_fitness_idx = "mean fitness"
best_fitness_idx = "best fitness"

# %%
fig, ax = plt.subplots()
fig.set_size_inches(12, 6)

ax.plot(progress[mean_fitness_idx], label="mean")
ax.plot(progress[best_fitness_idx], label="best")
ax.set_ylabel("fitness", color='r')

ax.set_title("Optimization progress")
ax.set_xlabel("iteration");

# %%
progress_path = os.path.join(res_dir, "progress.png")
fig.savefig(progress_path, bbox_inches='tight', dpi=200)
