# %%
# import libraries
import numpy as np
np.set_printoptions(precision = 4, suppress = True)
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy.stats import gaussian_kde

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
out_dir = "./data/out"
optim_dir = os.path.join(out_dir,"genetic-algorithm")
res_dir = os.path.join(optim_dir, "54")

# %%
progress = pd.read_csv(os.path.join(res_dir, "progress.csv"))
progress.tail(10)
# Out:
#     mean fitness  best fitness  population size
# 30    678.055765    997.255188              892
# 31    689.924287    997.255188              896
# 32    685.815485    997.255188              900
# 33    693.889628    997.255188              904
# 34    699.779613    997.255188              908
# 35    688.936927    997.255188              912
# 36    691.624236    997.255188              916
# 37    686.514945    997.255188              920
# 38    695.921423    997.255188              924
# 39    688.085814    997.255188              928

# %%
mean_fitness_idx = "mean fitness"
best_fitness_idx = "best fitness"

# %%
fig, ax1 = plt.subplots()
fig.set_size_inches(12, 6)

ax2 = ax1.twinx()
ax1.plot(progress[mean_fitness_idx], 'r-')
ax1.set_ylabel(mean_fitness_idx, color='r')
ax2.plot(progress[best_fitness_idx], 'c-')
ax2.set_ylabel(best_fitness_idx, color='c')

ax1.set_title("Optimization progress")
ax1.set_xlabel("iteration");

# %%
progress_path = os.path.join(res_dir, "progress.png")
fig.savefig(progress_path, bbox_inches='tight', dpi=200)
