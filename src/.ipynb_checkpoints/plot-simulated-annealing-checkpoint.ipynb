# %%
# import libraries
import numpy as np
np.set_printoptions(precision = 4, suppress = True)
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

#%matplotlib qt

# %%
out_dir = "./data/out"
optim_dir = os.path.join(out_dir,"simulated-annealing")
res_dir = os.path.join(optim_dir, "01")

# %%
net_profit = pd.read_csv(os.path.join(res_dir, "curr-state.csv"))
net_profit.head()
# Out:
#     net profit
# 0  1170.880981
# 1   512.339905
# 2  9061.271484
# 3   640.815063
# 4  1496.526978

# %%
fig, ax = plt.subplots()
ax.plot(net_profit)
ax.set_title("Current state net profit")
ax.set_xlabel("iteration")
ax.set_ylabel("net profit")
# Out:
# Text(0, 0.5, 'net profit')
