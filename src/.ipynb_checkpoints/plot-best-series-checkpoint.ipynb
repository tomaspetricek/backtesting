# %%
# import libraries
import numpy as np
np.set_printoptions(precision = 4, suppress = True)
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# import modules
from widgets import CandlestickWidget

import mplfinance as mpf

# %%
out_dir = "./data/out/brute force/51"
series_dir = os.path.join(out_dir, "best-series")
in_dir = "./data/in"
candles_path = os.path.join(in_dir, "ohlcv-eth-usdt-1-min.csv")
base_name = "ETH"
quote_name = "USDT"
asset_name = "{}/{}".format(base_name, quote_name)

# %%
def get_series(csv_path, sep=',', time_col="time"):
    series = pd.read_csv(csv_path, sep)
    series.drop(index=0)
    series[time_col] = pd.to_datetime(series[time_col], unit='s')
    series.set_index(time_col, inplace=True)
    return series

# %%
column_names = ["time", "open", "high", "low", "close"]
candle_series = pd.read_csv(candles_path, '|', names=column_names, usecols=range(5), header=None)
candle_series.set_index("time", inplace=True)
candle_series.index = pd.to_datetime(candle_series.index,unit='s')

# %%
candle_series.head()
# Out:
#                        open    high     low   close
# time
# 2017-08-17 04:00:00  301.13  301.13  301.13  301.13
# 2017-08-17 04:01:00  301.13  301.13  301.13  301.13
# 2017-08-17 04:02:00  300.00  300.00  300.00  300.00
# 2017-08-17 04:03:00  300.00  300.00  300.00  300.00
# 2017-08-17 04:04:00  301.13  301.13  301.13  301.13

# %%
# get series
close_balance_series = get_series(os.path.join(series_dir, "close-balance-series.csv"))
equity_series = get_series(os.path.join(series_dir, "equity-series.csv"))
open_order_series = get_series(os.path.join(series_dir, "open-order-series.csv"))
close_order_series = get_series(os.path.join(series_dir, "close-order-series.csv"))
exit_indic_series = get_series(os.path.join(series_dir, "exit-indic-series.csv"))
entry_indic_series = get_series(os.path.join(series_dir, "entry-indic-series.csv"))

# %%
# rename index
index_name = "Čas"
close_balance_series.index.name = index_name
equity_series.index.name = index_name
open_order_series.index.name = index_name
close_order_series.index.name = index_name
exit_indic_series.index.name = index_name
entry_indic_series.index.name = index_name

# %%
# rename columns
time_col = "Čas"
entry_level_pattern = "{}. vstupní úroveň"

entry_column_names = []
for i in range(len(entry_indic_series.columns)):
        entry_column_names.append(entry_level_pattern.format(i+1))

equity_column_name = "Čistá hodnota"
equity_series.columns = [equity_column_name]
close_balance_column_name = "Zůstatek po uzavření pozice"
close_balance_series.columns = [close_balance_column_name]
open_order_series.columns = ["Otevírací objednávka"]
close_order_series.columns = ["Uzavírací objednávka"]
exit_indic_series.columns = ["Výstupní úroveň"]
entry_indic_series.columns = entry_column_names

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 15))
data_name = ""
fig.suptitle("{}".format(asset_name), fontsize=16)

amount_name = "Částka ({})".format(quote_name)
price_name = "Cena ({})".format(quote_name)

ax1.step(equity_series.index, equity_series[equity_column_name], where="post", label="Čistá hodnota")
ax1.legend()
ax1.set_ylabel(amount_name)

ax2.step(close_balance_series.index, close_balance_series[close_balance_column_name], where="post",
         label="Zůstatek po uzavření pozice")
ax2.legend()
ax2.set_ylabel(amount_name)

ax3.plot(candle_series.index, candle_series['close'], label="Uzavírací cena svíčky");
ax3.legend()
ax3.set_ylabel(price_name)

fig.tight_layout()

# %%
fig.savefig(os.path.join(out_dir, "historical-simulation.png"), bbox_inches='tight', dpi=200)

# %%
# reindex
entry_indic_series = entry_indic_series.reindex(candle_series.index)
open_order_series = open_order_series.reindex(candle_series.index)
close_order_series = close_order_series.reindex(candle_series.index)
exit_indic_series = exit_indic_series.reindex(candle_series.index)
entry_indic_series = entry_indic_series.reindex(candle_series.index)

# %%
# %matplotlib qt

minute = 60
day = minute*24
week = day*7
month = week*4
year = day*365

visible_points_count = [week, month]
title = asset_name

for points_count in visible_points_count:
    widget = CandlestickWidget(candle_series, entry_indic_series, exit_indic_series, open_order_series,
                           close_order_series, title, points_count)
    widget.show()
# Out:
# 2023-04-14 11:04:51.086 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:04:51.248 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:06:44.758 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:06:44.909 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:06:51.773 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:07:02.482 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:11.664 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:11.812 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:21.748 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:24.059 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:24.942 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:48.630 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:51.166 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:53.576 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:10:59.552 Python[4156:11951908] +[CATransaction synchronize] called within transaction
# 2023-04-14 11:11:00.416 Python[4156:11951908] +[CATransaction synchronize] called within transaction
