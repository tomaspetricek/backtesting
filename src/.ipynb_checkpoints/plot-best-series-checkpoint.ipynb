# %%
# import libraries
import numpy as np
np.set_printoptions(precision = 4, suppress = True)
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# import modules
from widgets import CandlestickWidget

import mplfinance as mpf

# %%
out_dir = "./data/out/brute force/56"
series_dir = os.path.join(out_dir, "best-series")
in_dir = "./data/in"
candles_path = os.path.join(in_dir, "ohlcv-eth-usdt-1-min.csv")

# %%
def get_series(csv_path, sep=',', time_col="time"):
    series = pd.read_csv(csv_path, sep)
    series.drop(index=0)
    series[time_col] = pd.to_datetime(series[time_col], unit='s')
    series.set_index(time_col, inplace=True)
    return series

# %%
column_names = ["time", "open", "high", "low", "close"]
candle_series = pd.read_csv(candles_path, '|', names=column_names, usecols=range(5), header=None)
candle_series.set_index("time", inplace=True)
candle_series.index = pd.to_datetime(candle_series.index,unit='s')

# %%
candle_series.head(10)
# Out:
#                        open    high     low   close
# time
# 2017-08-17 04:00:00  301.13  301.13  301.13  301.13
# 2017-08-17 04:01:00  301.13  301.13  301.13  301.13
# 2017-08-17 04:02:00  300.00  300.00  300.00  300.00
# 2017-08-17 04:03:00  300.00  300.00  300.00  300.00
# 2017-08-17 04:04:00  301.13  301.13  301.13  301.13
# 2017-08-17 04:05:00  300.00  301.13  300.00  301.13
# 2017-08-17 04:06:00  300.10  300.10  300.10  300.10
# 2017-08-17 04:07:00  300.10  300.10  300.10  300.10
# 2017-08-17 04:08:00  300.10  300.10  298.00  298.00
# 2017-08-17 04:09:00  298.00  298.00  298.00  298.00

# %%
# get series
close_balance_series = get_series(os.path.join(series_dir, "close-balance-series.csv"))
equity_series = get_series(os.path.join(series_dir, "equity-series.csv"))
open_order_series = get_series(os.path.join(series_dir, "open-order-series.csv"))
close_order_series = get_series(os.path.join(series_dir, "close-order-series.csv"))
exit_indic_series = get_series(os.path.join(series_dir, "exit-indic-series.csv"))
entry_indic_series = get_series(os.path.join(series_dir, "entry-indic-series.csv"))

# %%
entry_indic_series
# Out:
#                      entry level 1  entry level 2  entry level 3
# time
# 2017-08-17 22:44:00     280.219574     253.349197     226.478836
# 2017-08-17 22:59:00     280.182037     253.315262     226.448502
# 2017-08-17 23:14:00     280.172333     253.306473     226.440643
# 2017-08-17 23:29:00     280.126038     253.264633     226.403229
# 2017-08-17 23:44:00     280.036530     253.183701     226.330887
# ...                            ...            ...            ...
# 2022-10-28 11:21:00    1374.370361    1242.581421    1110.792480
# 2022-10-28 11:36:00    1373.815674    1242.079834    1110.344116
# 2022-10-28 11:51:00    1373.472168    1241.769287    1110.066528
# 2022-10-28 12:06:00    1373.096069    1241.429321    1109.762573
# 2022-10-28 12:21:00    1372.839111    1241.197021    1109.554932
#
# [181602 rows x 3 columns]

# %%
# plot last position
# fig, ax = plt.subplots(figsize=(12, 6))
# ax.step(equity_series.index, equity_series["equity"], where="post", label="equity")
# ax.legend();

# %%
# fig.savefig(os.path.join(out_dir, "equity.png"), bbox_inches='tight', dpi=200)

# %%
entry_indic_series = entry_indic_series.reindex(candle_series.index)

# %%
entry_indic_series
# Out:
#                      entry level 1  entry level 2  entry level 3
# time
# 2017-08-17 04:00:00            NaN            NaN            NaN
# 2017-08-17 04:01:00            NaN            NaN            NaN
# 2017-08-17 04:02:00            NaN            NaN            NaN
# 2017-08-17 04:03:00            NaN            NaN            NaN
# 2017-08-17 04:04:00            NaN            NaN            NaN
# ...                            ...            ...            ...
# 2022-10-28 12:23:00            NaN            NaN            NaN
# 2022-10-28 12:24:00            NaN            NaN            NaN
# 2022-10-28 12:25:00            NaN            NaN            NaN
# 2022-10-28 12:26:00            NaN            NaN            NaN
# 2022-10-28 12:27:00            NaN            NaN            NaN
#
# [2725146 rows x 3 columns]

# %%
# %matplotlib qt
widget = CandlestickWidget(candle_series, entry_indic_series, exit_indic_series, open_order_series,
                           close_order_series, "historical simulation")
widget.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 get_ipython().run_line_magic('matplotlib', 'qt')
# ----> 2 widget = CandlestickWidget(candle_series, entry_indic_series, exit_indic_series, open_order_series,
#       3                            close_order_series, "historical simulation")
#       4 widget.show()
#
# File ~/CVUT/CVUT-2022-2023/zimni_semestr/diplomova-prace/backtesting/src/widgets.py:23, in CandlestickWidget.__init__(self, candle_series, entry_indic_series, exit_indic_series, open_order_series, close_order_series, fig_title, n_points_visible)
#      21 self._create_labels()
#      22 self._create_figure(fig_title)
# ---> 23 self._create_slider()
#
# File ~/CVUT/CVUT-2022-2023/zimni_semestr/diplomova-prace/backtesting/src/widgets.py:67, in CandlestickWidget._create_slider(self)
#      64 self._time_slider.on_changed(self._update)
#      66 # make initial update
# ---> 67 self._update(slider_min_val)
#
# File ~/CVUT/CVUT-2022-2023/zimni_semestr/diplomova-prace/backtesting/src/widgets.py:88, in CandlestickWidget._update(self, min_pos)
#      86 min_time = num2date(min_pos)
#      87 max_time = num2date(min_pos) + self._delta_time
# ---> 88 self._plot_data_points(min_time, max_time)
#      89 self._time_slider.valtext.set_text(min_time.strftime("%m/%d/%Y, %H:%M:%S"))
#      90 self._fig.canvas.draw_idle()
#
# File ~/CVUT/CVUT-2022-2023/zimni_semestr/diplomova-prace/backtesting/src/widgets.py:81, in CandlestickWidget._plot_data_points(self, min_time, max_time)
#      70 self._ax.clear()
#      71 addons = [
#      72     mpf.make_addplot(self._entry_indic_series.loc[min_time:max_time], ax=self._ax,
#      73                      type='scatter', markersize=1, marker='*'),
#    (...)
#      79     #                  type='scatter', markersize=200, marker='^'),
#      80 ]
# ---> 81 mpf.plot(self._candle_series.loc[min_time:max_time], ax=self._ax,
#      82          addplot=addons, type='candle', style='binance')
#      83 self._ax.legend(self._labels, loc='center left', bbox_to_anchor=(1, 0.5))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mplfinance/plotting.py:720, in plot(data, **kwargs)
#     718             for column in apdata:
#     719                 ydata = apdata.loc[:,column] if havedf else column
# --> 720                 ax = _addplot_columns(panid,panels,ydata,apdict,xdates,config)
#     721                 _addplot_apply_supplements(ax,apdict,xdates)
#     723 # fill_between is NOT supported for external_axes_mode
#     724 # (caller can easily call ax.fill_between() themselves).
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mplfinance/plotting.py:1042, in _addplot_columns(panid, panels, ydata, apdict, xdates, config)
#    1040         _mscatter(xdates, ydata, ax=ax, m=mark, s=size, color=color, alpha=alpha, edgecolors=edgecolors, linewidths=linewidths)
#    1041     else:
# -> 1042         ax.scatter(xdates, ydata, s=size, marker=mark, color=color, alpha=alpha, edgecolors=edgecolors, linewidths=linewidths)
#    1043 elif aptype == 'bar':
#    1044     width  = 0.8 if apdict['width'] is None else apdict['width']
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4368, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4366 y = np.ma.ravel(y)
#    4367 if x.size != y.size:
# -> 4368     raise ValueError("x and y must be the same size")
#    4370 if s is None:
#    4371     s = (20 if rcParams['_internal.classic_mode'] else
#    4372          rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
